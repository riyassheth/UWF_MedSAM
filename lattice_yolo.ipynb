# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 23.4 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install -U ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 64.7 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.8
#     Uninstalling widgetsnbextension-3.6.8:
#       Successfully uninstalled widgetsnbextension-3.6.8
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab_widgets 3.0.11
#     Uninstalling jupyterlab_widgets-3.0.11:
#       Successfully uninstalled jupyterlab_widgets-3.0.11
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
import ultralytics
from ultralytics import YOLO
from ultralytics import settings
settings.update({"wandb": False})
model = YOLO('yolov8x-seg.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 137M/137M [00:10<00:00, 13.7MB/s]

# %%
model.train(data = '/kaggle/input/yamlfinal/datayamlfinal.yaml', epochs = 150, imgsz = 640,  verbose = False)
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r train.zip /kaggle/working/runs/segment/train
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
#   adding: kaggle/working/runs/segment/train/ (stored 0%)
#   adding: kaggle/working/runs/segment/train/BoxR_curve.png (deflated 20%)
#   adding: kaggle/working/runs/segment/train/MaskF1_curve.png (deflated 20%)
#   adding: kaggle/working/runs/segment/train/labels_correlogram.jpg (deflated 44%)
#   adding: kaggle/working/runs/segment/train/BoxP_curve.png (deflated 16%)
#   adding: kaggle/working/runs/segment/train/results.png (deflated 5%)
#   adding: kaggle/working/runs/segment/train/val_batch2_pred.jpg (deflated 42%)
#   adding: kaggle/working/runs/segment/train/MaskPR_curve.png (deflated 22%)
#   adding: kaggle/working/runs/segment/train/train_batch2.jpg (deflated 30%)
#   adding: kaggle/working/runs/segment/train/labels.jpg (deflated 35%)
# ...

# %%
# !ls

# %%
model.val()
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71,722,582 parameters, 0 gradients, 343.7 GFLOPs
# val: Scanning /kaggle/input/lattice-yolo-segmentation-final/lattice_yolo_segmentation_final/val/labels... 95 images, 77 backgrounds, 0 corrupt: 100%|██████████| 95/95 [00:00<00:00, 715.25it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/lattice-yolo-segmentation-final/lattice_yolo_segmentation_final/val is not writeable, cache not saved.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.73it/s]
# ...

# %%
# !zip -r val.zip /kaggle/working/runs/segment/train2
# Out:
#   adding: kaggle/working/runs/segment/train2/ (stored 0%)
#   adding: kaggle/working/runs/segment/train2/BoxR_curve.png (deflated 20%)
#   adding: kaggle/working/runs/segment/train2/MaskF1_curve.png (deflated 20%)
#   adding: kaggle/working/runs/segment/train2/BoxP_curve.png (deflated 16%)
#   adding: kaggle/working/runs/segment/train2/val_batch2_pred.jpg (deflated 39%)
#   adding: kaggle/working/runs/segment/train2/MaskPR_curve.png (deflated 22%)
#   adding: kaggle/working/runs/segment/train2/confusion_matrix.png (deflated 39%)
#   adding: kaggle/working/runs/segment/train2/BoxF1_curve.png (deflated 20%)
#   adding: kaggle/working/runs/segment/train2/val_batch1_pred.jpg (deflated 40%)
#   adding: kaggle/working/runs/segment/train2/BoxPR_curve.png (deflated 23%)
#   adding: kaggle/working/runs/segment/train2/val_batch0_labels.jpg (deflated 38%)
#   adding: kaggle/working/runs/segment/train2/val_batch1_labels.jpg (deflated 40%)
# ...
